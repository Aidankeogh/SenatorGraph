# %% [markdown]
# # Get Concise List of Politicians and Candidates

# %% [markdown]
# This notebook processes the S117_members and 2022-senate-races files and matches them with the candidate_twitters files so that we can have a concise list of politicians/candidates whose recent tweets we can pull based on their twitter IDs

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load in datasets

# %%
senate_races = pd.read_csv("2022-senate-races.csv")
senate_races.head()
# Out:
#      STATE First name   Last name Party Incumbent
# 0  Alabama       Will        Boyd   Dem         N
# 1  Alabama      Katie       Britt   Rep         N
# 2  Alabama       John  Sophocleus   Lib         N
# 3   Alaska   Patricia     Chesbro   Dem         N
# 4   Alaska       Buzz      Kelley   Rep         N

# %%
len(senate_races)
# Out:
# 136

# %%
senate_members = pd.read_csv("S117_members.csv")
senate_members.head()
# Out:
#    congress    chamber  icpsr  state_icpsr  district_code state_abbrev  \
# 0       117  President  99912           99              0          USA
# 1       117  President  99913           99              0          USA
# 2       117     Senate  42102           41              0           AL
# 3       117     Senate  94659           41              0           AL
# 4       117     Senate  40300           81              0           AK
#
#    party_code  occupancy  last_means                            bioname  ...  \
# 0         200        0.0         0.0                 TRUMP, Donald John  ...
# 1         100        0.0         0.0       BIDEN, Joseph Robinette, Jr.  ...
# 2         200        NaN         NaN  TUBERVILLE, Thomas Hawley (Tommy)  ...
# 3         200        NaN         NaN                 SHELBY, Richard C.  ...
# 4         200        NaN         NaN                    MURKOWSKI, Lisa  ...
#
#   died  nominate_dim1  nominate_dim2  nominate_log_likelihood  \
# 0  NaN          0.403          0.162                      NaN
# 1  NaN         -0.320          0.283                      NaN
# 2  NaN          0.936         -0.352                -75.54402
# 3  NaN          0.448          0.576               -140.62321
# 4  NaN          0.210         -0.302               -125.63009
#
#    nominate_geo_mean_probability  nominate_number_of_votes  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                        0.90957                     797.0
# 3                        0.82903                     750.0
# 4                        0.84745                     759.0
#
#    nominate_number_of_errors  conditional  nokken_poole_dim1  \
# 0                        NaN          NaN                NaN
# 1                        NaN          NaN                NaN
# 2                       28.0          NaN              0.874
# 3                       74.0          NaN              0.540
# 4                       57.0          NaN              0.209
#
#    nokken_poole_dim2
# 0                NaN
# 1                NaN
# 2             -0.213
# 3              0.506
# 4             -0.365
#
# [5 rows x 22 columns]

# %%
len(senate_members)
# Out:
# 104

# %%
twitter_accounts = pd.read_csv("candidate_twitters.csv")
twitter_accounts.head()
# Out:
#                  Name Twitter_username    Account_start_time  \
# 0  A. Donald McEachin      RepMcEachin  2017-01-03T00:00:00Z
# 1    Aaron Michlewitz    RepMichlewitz  2010-06-27T00:00:00Z
# 2        Aaron Peskin      AaronPeskin  2010-11-13T00:00:00Z
# 3          Aaron Peña        AaronPena  2007-10-31T00:00:00Z
# 4        Aaron Schock      aaronschock  2009-03-12T00:00:00Z
#
#            Account_ID   Sex                Birthplace              Birthday  \
# 0  816181091673448448  male                   Germany  1961-10-10T00:00:00Z
# 1           160246973  male  United States of America  1978-01-01T00:00:00Z
# 2           215369273  male  United States of America  1964-06-17T00:00:00Z
# 3             9843332  male  United States of America  1959-06-08T00:00:00Z
# 4            23951197  male  United States of America  1981-05-28T00:00:00Z
#
#     Age Instagram_username   Political_party
# 0  59.0        repmceachin  Democratic Party
# 1  42.0                NaN  Democratic Party
# 2  56.0          apeskin52  Democratic Party
# 3  61.0                NaN  Republican Party
# 4  39.0        aaronschock  Republican Party

# %%
twitter_names = twitter_accounts[['Name', 'Twitter_username']]

# %%
twitter_names.head()
# Out:
#                  Name Twitter_username
# 0  A. Donald McEachin      RepMcEachin
# 1    Aaron Michlewitz    RepMichlewitz
# 2        Aaron Peskin      AaronPeskin
# 3          Aaron Peña        AaronPena
# 4        Aaron Schock      aaronschock

# %%
senate_members = senate_members.iloc[:, :10]

# %%
senate_members.head()
# Out:
#    congress    chamber  icpsr  state_icpsr  district_code state_abbrev  \
# 0       117  President  99912           99              0          USA
# 1       117  President  99913           99              0          USA
# 2       117     Senate  42102           41              0           AL
# 3       117     Senate  94659           41              0           AL
# 4       117     Senate  40300           81              0           AK
#
#    party_code  occupancy  last_means                            bioname
# 0         200        0.0         0.0                 TRUMP, Donald John
# 1         100        0.0         0.0       BIDEN, Joseph Robinette, Jr.
# 2         200        NaN         NaN  TUBERVILLE, Thomas Hawley (Tommy)
# 3         200        NaN         NaN                 SHELBY, Richard C.
# 4         200        NaN         NaN                    MURKOWSKI, Lisa

# %% [markdown]
# ### Preprocess the senator name data so that the name are more consistent with the twitter names

# %%
senate_races['Full name'] = senate_races['First name']+" "+senate_races['Last name']

# %%
senate_races.head()
# Out:
#      STATE First name   Last name Party Incumbent         Full name
# 0  Alabama       Will        Boyd   Dem         N         Will Boyd
# 1  Alabama      Katie       Britt   Rep         N       Katie Britt
# 2  Alabama       John  Sophocleus   Lib         N   John Sophocleus
# 3   Alaska   Patricia     Chesbro   Dem         N  Patricia Chesbro
# 4   Alaska       Buzz      Kelley   Rep         N       Buzz Kelley

# %%
senate_cands = list(senate_races['Full name'])
twitter_cands = list(twitter_names['Name'])

# %%
len(list(set(senate_cands) & set(twitter_cands)))
# Out:
# 32

# %% [markdown]
# ### Add last name column to senate members dataset and twitter name dataset and use last name as primary matching criteria.  Since the final list is rather small, I can manually evaluate the matching.

# %%
# Add 'Last name' column to twitter accounts dataset

last_name = []
for ind in twitter_names.index:
    name = twitter_names['Name'][ind]
    last = name.split(" ")
    last = last[len(last)-1]
    last_name.append(last)
    
twitter_names['Last name'] = last_name
twitter_names.head()
# Out:
# /var/folders/6w/pjm4r6dn0zd8yc5l111vlffh0000gn/T/ipykernel_31375/3289804705.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twitter_names['Last name'] = last_name
#                  Name Twitter_username   Last name
# 0  A. Donald McEachin      RepMcEachin    McEachin
# 1    Aaron Michlewitz    RepMichlewitz  Michlewitz
# 2        Aaron Peskin      AaronPeskin      Peskin
# 3          Aaron Peña        AaronPena        Peña
# 4        Aaron Schock      aaronschock      Schock

# %%
# Add 'Last name' column to senate members dataset

last_name = []
for ind in senate_members.index:
    name = senate_members['bioname'][ind]
    last = name.split(" ")
    last = last[0].title()
    last = last.split(",")[0]
    last_name.append(last)
    
senate_members['Last name'] = last_name
senate_members.head()
# Out:
#    congress    chamber  icpsr  state_icpsr  district_code state_abbrev  \
# 0       117  President  99912           99              0          USA
# 1       117  President  99913           99              0          USA
# 2       117     Senate  42102           41              0           AL
# 3       117     Senate  94659           41              0           AL
# 4       117     Senate  40300           81              0           AK
#
#    party_code  occupancy  last_means                            bioname  \
# 0         200        0.0         0.0                 TRUMP, Donald John
# 1         100        0.0         0.0       BIDEN, Joseph Robinette, Jr.
# 2         200        NaN         NaN  TUBERVILLE, Thomas Hawley (Tommy)
# 3         200        NaN         NaN                 SHELBY, Richard C.
# 4         200        NaN         NaN                    MURKOWSKI, Lisa
#
#     Last name
# 0       Trump
# 1       Biden
# 2  Tuberville
# 3      Shelby
# 4   Murkowski

# %%
senate_races_twitter = senate_races.merge(twitter_names, on = ['Last name'] )
senate_races_twitter = senate_races_twitter.drop_duplicates()
senate_races_twitter.head(10)
# Out:
#       STATE First name  Last name Party Incumbent       Full name  \
# 0    Alaska       Lisa  Murkowski   Rep         Y  Lisa Murkowski
# 1    Alaska        Sid       Hill   Ind         N        Sid Hill
# 2    Alaska        Sid       Hill   Ind         N        Sid Hill
# 3    Alaska        Sid       Hill   Ind         N        Sid Hill
# 4    Alaska        Sid       Hill   Ind         N        Sid Hill
# 5   Arizona       Mark      Kelly   Dem         Y      Mark Kelly
# 6   Arizona       Mark      Kelly   Dem         Y      Mark Kelly
# 8   Arizona       Mark      Kelly   Dem         Y      Mark Kelly
# 9   Arizona       Mark      Kelly   Dem         Y      Mark Kelly
# 10  Arizona       Mark      Kelly   Dem         Y      Mark Kelly
#
#               Name Twitter_username
# 0   Lisa Murkowski    lisamurkowski
# 1    Bradford Hill      repbradhill
# 2      Curtis Hill    CurtisHill_IN
# 3      French Hill    RepFrenchHill
# 4       Katie Hill     RepKatieHill
# 5      Laura Kelly    GovLauraKelly
# 6       Mark Kelly    CaptMarkKelly
# 8       Mike Kelly      MikeKellyPA
# 9      Robin Kelly    RepRobinKelly
# 10       Tim Kelly     timothykelly

# %%
senate_members_twitter = senate_members.merge(twitter_names, on = ['Last name'] )
senate_members_twitter = senate_members_twitter.drop_duplicates()
senate_members_twitter.head(10)
# Out:
#     congress    chamber  icpsr  state_icpsr  district_code state_abbrev  \
# 0        117  President  99912           99              0          USA
# 1        117  President  99912           99              0          USA
# 4        117  President  99912           99              0          USA
# 6        117  President  99913           99              0          USA
# 7        117  President  99913           99              0          USA
# 11       117     Senate  42102           41              0           AL
# 12       117     Senate  94659           41              0           AL
# 14       117     Senate  40300           81              0           AK
# 15       117     Senate  41500           81              0           AK
# 17       117     Senate  41500           81              0           AK
#
#     party_code  occupancy  last_means                            bioname  \
# 0          200        0.0         0.0                 TRUMP, Donald John
# 1          200        0.0         0.0                 TRUMP, Donald John
# 4          200        0.0         0.0                 TRUMP, Donald John
# 6          100        0.0         0.0       BIDEN, Joseph Robinette, Jr.
# 7          100        0.0         0.0       BIDEN, Joseph Robinette, Jr.
# 11         200        NaN         NaN  TUBERVILLE, Thomas Hawley (Tommy)
# 12         200        NaN         NaN                 SHELBY, Richard C.
# 14         200        NaN         NaN                    MURKOWSKI, Lisa
# 15         200        NaN         NaN             SULLIVAN, Daniel Scott
# 17         200        NaN         NaN             SULLIVAN, Daniel Scott
#
#      Last name                Name Twitter_username
# 0        Trump        Donald Trump  realDonaldTrump
# 1        Trump        Donald Trump            POTUS
# 4        Trump        Ivanka Trump      IvankaTrump
# 6        Biden          Jill Biden          drbiden
# 7        Biden           Joe Biden         JoeBiden
# 11  Tuberville    Tommy Tuberville      TTuberville
# 12      Shelby      Richard Shelby        SenShelby
# 14   Murkowski      Lisa Murkowski    lisamurkowski
# 15    Sullivan  Daniel S. Sullivan   SenDanSullivan
# 17    Sullivan        Rip Sullivan    RipSullivan48

# %%
len(senate_races_twitter)
# Out:
# 137

# %%
len(senate_members_twitter)
# Out:
# 215

# %% [markdown]
# ### SAve the twitter matching results and manually inspect to fix errors

# %%
senate_races_twitter.to_csv("senator_races_twitters.csv", index = False)
senate_members_twitter.to_csv("senator_members_twitters.csv", index = False)
