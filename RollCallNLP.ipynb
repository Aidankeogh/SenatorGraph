# %% [markdown]
# # Congressional Roll Calls NLP Analysis

# %% [markdown]
# This notebooks takes the S117_rollcalls.csv data set, which contains bills that have gone through the senate, and performs some Natural Language Processing on the bill descriptions, namely a Name Entity Relationship analysis with Transformers.

# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
from spacy import tokenizer
import re
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2022-11-30 16:05:24.435366: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Load in and process the S117_rollcalls data

# %%
rollcalls = pd.read_csv("S117_rollcalls.csv")
rollcalls.head()
# Out:
#    congress chamber  rollnumber        date  session  clerk_rollnumber  \
# 0       117  Senate           1  2021-01-06        1                 1
# 1       117  Senate           2  2021-01-07        1                 2
# 2       117  Senate           3  2021-01-20        1                 3
# 3       117  Senate           4  2021-01-21        1                 4
# 4       117  Senate           5  2021-01-22        1                 5
#
#    yea_count  nay_count  nominate_mid_1  nominate_mid_2  nominate_spread_1  \
# 0          6         93          -0.695           0.620              0.115
# 1          7         92          -0.767           0.609              0.119
# 2         84         10           0.541           0.841              0.450
# 3         69         27          -0.787           0.617             -0.132
# 4         93          2           0.000           0.000              0.000
#
#    nominate_spread_2  nominate_log_likelihood bill_number  \
# 0             -1.472                  -18.659         NaN
# 1             -1.265                  -19.668         NaN
# 2              0.340                  -14.842      PN7810
# 3             -0.259                  -51.575       HR335
# 4              0.000                    0.000       PN781
#
#                vote_result                                          vote_desc  \
# 0  Objection Not Sustained                                                NaN
# 1  Objection Not Sustained                                                NaN
# 2     Nomination Confirmed  Avril Danica Haines, of New York, to be Direct...
# 3              Bill Passed  A bill to provide for an exception to a limita...
# 4     Nomination Confirmed  Lloyd James Austin, of Georgia, to be Secretar...
#
#             vote_question  dtl_desc
# 0        On the Objection       NaN
# 1        On the Objection       NaN
# 2       On the Nomination       NaN
# 3  On Passage of the Bill       NaN
# 4       On the Nomination       NaN

# %%
rollcalls = rollcalls[rollcalls['vote_desc'].notna()]

# %%
rollcalls.head()
# Out:
#    congress chamber  rollnumber        date  session  clerk_rollnumber  \
# 2       117  Senate           3  2021-01-20        1                 3
# 3       117  Senate           4  2021-01-21        1                 4
# 4       117  Senate           5  2021-01-22        1                 5
# 5       117  Senate           6  2021-01-25        1                 6
# 6       117  Senate           7  2021-01-26        1                 7
#
#    yea_count  nay_count  nominate_mid_1  nominate_mid_2  nominate_spread_1  \
# 2         84         10           0.541           0.841              0.450
# 3         69         27          -0.787           0.617             -0.132
# 4         93          2           0.000           0.000              0.000
# 5         84         15          -0.045           0.999              0.129
# 6         78         22           0.444           0.426              0.222
#
#    nominate_spread_2  nominate_log_likelihood bill_number  \
# 2              0.340                  -14.842      PN7810
# 3             -0.259                  -51.575       HR335
# 4              0.000                    0.000       PN781
# 5              0.670                  -24.108      PN7824
# 6              0.340                  -22.975       PN783
#
#             vote_result                                          vote_desc  \
# 2  Nomination Confirmed  Avril Danica Haines, of New York, to be Direct...
# 3           Bill Passed  A bill to provide for an exception to a limita...
# 4  Nomination Confirmed  Lloyd James Austin, of Georgia, to be Secretar...
# 5  Nomination Confirmed  Janet Louise Yellen, of California, to be Secr...
# 6  Nomination Confirmed  Antony John Blinken, of New York, to be Secret...
#
#             vote_question  dtl_desc
# 2       On the Nomination       NaN
# 3  On Passage of the Bill       NaN
# 4       On the Nomination       NaN
# 5       On the Nomination       NaN
# 6       On the Nomination       NaN

# %%
rolls_dict = {}
for ind in rollcalls.index:
    rollnum = int(rollcalls['rollnumber'][ind])
    vote_desc = str(rollcalls['vote_desc'][ind])
    vote_desc = vote_desc.replace('\n', '').rstrip().lstrip()
    rolls_dict[rollnum] = vote_desc

# %%
rolls_dict[3]
# Out:
# 'Avril Danica Haines, of New York, to be Director of National Intelligence'

# %% [markdown]
# ## Conduct NER on roll calls

# %% [markdown]
# Spacy transformers ...

# %%
nlp = spacy.load('en_core_web_trf')

# %%
def build_ner_table(roll_data):
    
    ner_table = []
    
    for num in roll_data.keys():
        desc = roll_data[num]
        doc = nlp(desc)
        ners = list((num, desc, X.label_, X.text) for X in doc.ents)
        ner_df = pd.DataFrame(ners, columns = ['rollnumber', 'vote_desc', 'NER_Lable', 'Text'])
        ner_table.append(ner_df)
        
    ner_table = pd.concat(ner_table, ignore_index = True)
    
    return(ner_table)

# %%
rollcall_ners = build_ner_table(rolls_dict)

# %%
rollcall_ners.head(25)
# Out:
#    rollnumber                                          vote_desc NER_Lable  \
# 0           3  Avril Danica Haines, of New York, to be Direct...    PERSON
# 1           3  Avril Danica Haines, of New York, to be Direct...       GPE
# 2           4  A bill to provide for an exception to a limita...       ORG
# 3           4  A bill to provide for an exception to a limita...      DATE
# 4           4  A bill to provide for an exception to a limita...       ORG
# 5           5  Lloyd James Austin, of Georgia, to be Secretar...    PERSON
# 6           5  Lloyd James Austin, of Georgia, to be Secretar...       GPE
# 7           5  Lloyd James Austin, of Georgia, to be Secretar...       ORG
# 8           6  Janet Louise Yellen, of California, to be Secr...    PERSON
# 9           6  Janet Louise Yellen, of California, to be Secr...       GPE
# 10          6  Janet Louise Yellen, of California, to be Secr...       ORG
# 11          7  Antony John Blinken, of New York, to be Secret...    PERSON
# 12          7  Antony John Blinken, of New York, to be Secret...       GPE
# 13          7  Antony John Blinken, of New York, to be Secret...       ORG
# 14          9  A resolution to provide for related procedures...    PERSON
# 15          9  A resolution to provide for related procedures...       GPE
# 16         10  Alejandro Nicholas Mayorkas, of the District o...    PERSON
# 17         10  Alejandro Nicholas Mayorkas, of the District o...       GPE
# 18         10  Alejandro Nicholas Mayorkas, of the District o...       ORG
# 19         11  Peter Paul Montgomery Buttigieg, of Indiana, t...    PERSON
# 20         11  Peter Paul Montgomery Buttigieg, of Indiana, t...       GPE
# 21         11  Peter Paul Montgomery Buttigieg, of Indiana, t...       ORG
# 22         12  Alejandro Nicholas Mayorkas, of the District o...    PERSON
# 23         12  Alejandro Nicholas Mayorkas, of the District o...       GPE
# 24         12  Alejandro Nicholas Mayorkas, of the District o...       ORG
#
#                                Text
# 0               Avril Danica Haines
# 1                          New York
# 2                           Defense
# 3                       seven years
# 4                  the Armed Forces
# 5                Lloyd James Austin
# 6                           Georgia
# 7                           Defense
# 8               Janet Louise Yellen
# 9                        California
# 10                         Treasury
# 11              Antony John Blinken
# 12                         New York
# 13                            State
# 14                Donald John Trump
# 15                the United States
# 16      Alejandro Nicholas Mayorkas
# 17         the District of Columbia
# 18                Homeland Security
# 19  Peter Paul Montgomery Buttigieg
# 20                          Indiana
# 21                   Transportation
# 22      Alejandro Nicholas Mayorkas
# 23         the District of Columbia
# 24                Homeland Security

# %%
len(rollcall_ners)
# Out:
# 2319

# %%
rollcall_ners.groupby('NER_Lable').size()
# Out:
# NER_Lable
# CARDINAL         4
# DATE           173
# EVENT           11
# FAC             12
# GPE            931
# LAW             90
# LOC             12
# MONEY           10
# NORP            24
# ORDINAL          4
# ORG            527
# PERCENT          4
# PERSON         513
# PRODUCT          1
# WORK_OF_ART      3
# dtype: int64

# %%
rollcall_ners.to_csv("rollcall_ners.csv", index = False)
